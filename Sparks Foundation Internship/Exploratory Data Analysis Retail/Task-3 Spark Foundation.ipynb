# %% [markdown]
# **The Sparks Foundation Internship**

# %% [markdown]
# Task-3 Exploratory Data Analysis-Retail

# %% [markdown]
# - Perform Exploratory Data Analysis on dataset 'SampleSuperstore'

# %% [markdown]
# **Import the Required Packages**

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Read the data

# %%
df=pd.read_csv('SampleSuperstore.csv')

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.head()#First 5 rows
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.shape#No of rows, No of columns
# Out:
# (9994, 13)

# %%
df.columns#list of columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# **Exploratory Data Analysis**

# %%
df.dtypes#data types
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# **Divide variables into Categorical and Numerical**

# %%
cat_cols=[i for i in dict(df.dtypes) if dict(df.dtypes)[i]=='object']
num_cols=[i for i in dict(df.dtypes) if dict(df.dtypes)[i]!='object']

# %%
print(len(cat_cols))
cat_cols
# Out:
# 8
# ['Ship Mode',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Region',
#  'Category',
#  'Sub-Category']

# %%
print(len(num_cols))
num_cols
# Out:
# 5
# ['Postal Code', 'Sales', 'Quantity', 'Discount', 'Profit']

# %%
df[cat_cols]
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#      Region         Category Sub-Category
# ...

# %%
df['Ship Mode'].unique()#unique values
df['Ship Mode'].nunique()#count of unique values
# Out:
# 4

# %%
for i in cat_cols:
    print(i,df[i].unique(),df[i].nunique())
# Out:
# Ship Mode ['Second Class' 'Standard Class' 'First Class' 'Same Day'] 4
# Segment ['Consumer' 'Corporate' 'Home Office'] 3
# Country ['United States'] 1
# City ['Henderson' 'Los Angeles' 'Fort Lauderdale' 'Concord' 'Seattle'
#  'Fort Worth' 'Madison' 'West Jordan' 'San Francisco' 'Fremont'
#  'Philadelphia' 'Orem' 'Houston' 'Richardson' 'Naperville' 'Melbourne'
#  'Eagan' 'Westland' 'Dover' 'New Albany' 'New York City' 'Troy' 'Chicago'
#  'Gilbert' 'Springfield' 'Jackson' 'Memphis' 'Decatur' 'Durham' 'Columbia'
#  'Rochester' 'Minneapolis' 'Portland' 'Saint Paul' 'Aurora' 'Charlotte'
#  'Orland Park' 'Urbandale' 'Columbus' 'Bristol' 'Wilmington' 'Bloomington'
#  'Phoenix' 'Roseville' 'Independence' 'Pasadena' 'Newark' 'Franklin'
#  'Scottsdale' 'San Jose' 'Edmond' 'Carlsbad' 'San Antonio' 'Monroe'
#  'Fairfield' 'Grand Prairie' 'Redlands' 'Hamilton' 'Westfield' 'Akron'
#  'Denver' 'Dallas' 'Whittier' 'Saginaw' 'Medina' 'Dublin' 'Detroit'
# ...

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
value=df['Ship Mode'].value_counts()
ax=value.plot(kind='bar')
ax.bar_label(ax.containers[0])
plt.title('Bar chart')
plt.ylabel('count')
plt.show()

# %%
value=df['Segment'].value_counts()
ax=value.plot(kind='bar')
ax.bar_label(ax.containers[0])
plt.title('Bar Graph')
plt.xlabel('Segment')
plt.ylabel('Count')
plt.show()

# %%
d1=dict(df['Segment'].value_counts())
keys=d1.keys()
values=d1.values()
df1=pd.DataFrame(zip(keys,values),columns=['keys','values'])
plt.bar('keys','values',data=df1)
plt.title('Bar graph')
plt.xlabel('Frequency')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
cat_cols
# Out:
# ['Ship Mode',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Region',
#  'Category',
#  'Sub-Category']

# %%
plt.figure(figsize=(10,10))
for i in range(len(cat_cols)):
    plt.subplot(3,3,i+1)
    value=df[cat_cols[i]].value_counts()
    ax=value.plot(kind='bar')
    ax.bar_label(ax.containers[0])
    plt.xlabel(cat_cols[i])
    plt.ylabel('count')
    plt.title('bar Graph')
    plt.tight_layout()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4776\3432621716.py:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4776\3432621716.py:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4776\3432621716.py:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4776\3432621716.py:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4776\3432621716.py:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4776\3432621716.py:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4776\3432621716.py:10: UserWarning: The figure layout has changed to tight
# ...

# %%
plt.figure(figsize=(15,10))
for i in range(len(cat_cols)):
    plt.subplot(4,3,i+1)
    values=df[cat_cols[i]].value_counts().values
    names=df[cat_cols[i]].value_counts().keys()
    plt.pie(x=values,labels=names,autopct="%0.2f%%",shadow=True,startangle=30)
    plt.xlabel(cat_cols[i])
    plt.title('pie chart')
    plt.tight_layout()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4776\1228182939.py:9: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4776\1228182939.py:9: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4776\1228182939.py:9: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4776\1228182939.py:9: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4776\1228182939.py:9: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4776\1228182939.py:9: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4776\1228182939.py:9: UserWarning: The figure layout has changed to tight
# ...

# %%
num_cols
# Out:
# ['Postal Code', 'Sales', 'Quantity', 'Discount', 'Profit']

# %%
plt.figure(figsize=(10,5))
plt.suptitle('Histogram of all Numerical varibles')
for i in range(len(num_cols)):
    plt.subplot(2,3,i+1)
    data=df[num_cols[i]]
    plt.hist(data,bins=40)
    plt.title("histogram")
    plt.xlabel("Interval")
    plt.ylabel('Frequency')
    plt.tight_layout()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4776\3042969563.py:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
plt.figure(figsize=(10,3))
plt.suptitle('Boxplot')

for i in range(len(num_cols)):
    plt.subplot(2,3,i+1)
    plt.boxplot(df[num_cols[i]],vert=False)
    plt.title(num_cols[i])

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
q1=np.percentile(df['Sales'],25)
q2=np.percentile(df['Sales'],50)
q3=np.percentile(df['Sales'],75)
iqr=q3-q1
ub=q3+1.5*iqr
lb=q1-1.5*iqr
cond1=df['Sales']>ub
cond2=df['Sales']<ub
df['Sales'][cond1|cond2].values
len(df['Sales'][cond1|cond2].values)
# Out:
# 9994

# %%
len(df['Sales'][cond1|cond2].values)
# Out:
# 9994

# %%
for i in range(len(num_cols)):
    q1 = np.percentile(df[num_cols[i]],25)
    q2 = np.percentile(df[num_cols[i]],50)
    q3 = np.percentile(df[num_cols[i]],75)
    iqr= q3-q1
    ub= q3+1.5*iqr
    lb= q1-1.5*iqr
    con1=df[num_cols[i]]>ub
    con2=df[num_cols[i]]<lb
    outliers=df[num_cols[i]][con1|con2].values
    print(num_cols[i],len(outliers))
# Out:
# Postal Code 0
# Sales 1167
# Quantity 170
# Discount 856
# Profit 1881

# %%
q1 = np.percentile(df['Sales'],25)
q2 = np.percentile(df['Sales'],50)
q3 = np.percentile(df['Sales'],75)
iqr= q3-q1
ub= q3+1.5*iqr
lb= q1-1.5*iqr
con1=df['Sales']>ub
con2=df['Sales']<lb
median=df['Sales'].median()
df['Sales']=np.where(con1|con2,median,df['Sales'])

# %%
q1 = np.percentile(df['Quantity'],25)
q2 = np.percentile(df['Quantity'],50)
q3 = np.percentile(df['Quantity'],75)
iqr= q3-q1
ub= q3+1.5*iqr
lb= q1-1.5*iqr
con1=df['Quantity']>ub
con2=df['Quantity']<lb
median=df['Quantity'].median()
df['Quantity']=np.where(con1|con2,median,df['Quantity'])

# %%
q1 = np.percentile(df['Profit'],25)
q2 = np.percentile(df['Profit'],50)
q3 = np.percentile(df['Profit'],75)
iqr= q3-q1
ub= q3+1.5*iqr
lb= q1-1.5*iqr
con1=df['Profit']>ub
con2=df['Profit']<lb
median=df['Profit'].median()
df['Profit']=np.where(con1|con2,median,df['Profit'])

# %%
q1 = np.percentile(df['Discount'],25)
q2 = np.percentile(df['Discount'],50)
q3 = np.percentile(df['Discount'],75)
iqr= q3-q1
ub= q3+1.5*iqr
lb= q1-1.5*iqr
con1=df['Discount']>ub
con2=df['Discount']<lb
median=df['Discount'].median()
df['Discount']=np.where(con1|con2,median,df['Discount'])

# %%
plt.figure(figsize=(10,3))
plt.suptitle('After removing of outliers')
for i in range(len(num_cols)):
    plt.subplot(2,3,i+1)
    plt.boxplot(df[num_cols[i]],vert=False)
    plt.title(num_cols[i])
    plt.tight_layout()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4776\2478196075.py:7: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4776\2478196075.py:7: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4776\2478196075.py:7: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4776\2478196075.py:7: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
cat_cols
# Out:
# ['Ship Mode',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Region',
#  'Category',
#  'Sub-Category']

# %%
col1=df['Ship Mode']
col2=df['Segment']
result1=pd.crosstab(col1,col2)
result1
# Out:
# Segment         Consumer  Corporate  Home Office
# Ship Mode
# First Class          769        485          284
# Same Day             317        114          112
# Second Class        1020        609          316
# Standard Class      3085       1812         1071

# %%
result1.plot(kind='bar')
# Out:
# <Axes: xlabel='Ship Mode'>

# %%
col1=df['Region']
col2=df['Category']
result2=pd.crosstab(col1,col2)
result2
# Out:
# Category  Furniture  Office Supplies  Technology
# Region
# Central         481             1422         420
# East            601             1712         535
# South           332              995         293
# West            707             1897         599

# %%
result2.plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
num_cols
# Out:
# ['Postal Code', 'Sales', 'Quantity', 'Discount', 'Profit']

# %%
col1=df['Sales']
col2=df['Quantity']
plt.scatter(col1,col2)
plt.title('Scatter plot')
plt.xlabel('sales')
plt.ylabel('Quantity')
# Out:
# Text(0, 0.5, 'Quantity')

# %%
col1=df['Discount']
col2=df['Profit']
plt.scatter(col1,col2)
plt.title('Scatter plot')
plt.xlabel('Discount')
plt.ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# **Convert Categorical data into numerical**

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cat_cols:
    df[i]=le.fit_transform(df[i])

# %%
df.head()
# Out:
#    Ship Mode  Segment  Country  City  State  Postal Code  Region  Category  \
# 0          2        0        0   194     15        42420       2         0
# 1          2        0        0   194     15        42420       2         0
# 2          2        1        0   266      3        90036       3         1
# 3          3        0        0   153      8        33311       2         0
# 4          3        0        0   153      8        33311       2         1
#
#    Sub-Category    Sales  Quantity  Discount   Profit
# 0             4  261.960       2.0      0.00  41.9136
# 1             5   54.490       3.0      0.00   8.6665
# 2            10   14.620       2.0      0.00   6.8714
# 3            16   54.490       5.0      0.45   8.6665
# 4            14   22.368       2.0      0.20   2.5164

# %% [markdown]
# **Standardize the data**

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
for i in df.columns[:-1]:
    df[i]=ss.fit_transform(df[[i]])

# %%
df
# Out:
#       Ship Mode   Segment  Country      City     State  Postal Code    Region  \
# 0     -0.213513 -0.864161      0.0 -0.617727 -0.473638    -0.398302  0.369413
# 1     -0.213513 -0.864161      0.0 -0.617727 -0.473638    -0.398302  0.369413
# 2     -0.213513  0.447170      0.0 -0.100303 -1.247640     1.086817  1.229798
# 3      0.694896 -0.864161      0.0 -0.912371 -0.925139    -0.682407  0.369413
# 4      0.694896 -0.864161      0.0 -0.912371 -0.925139    -0.682407  0.369413
# ...         ...       ...      ...       ...       ...          ...       ...
# 9989  -0.213513 -0.864161      0.0  0.108104 -0.925139    -0.686492  0.369413
# 9990   0.694896 -0.864161      0.0 -1.264507 -1.247640     1.167629  1.229798
# 9991   0.694896 -0.864161      0.0 -1.264507 -1.247640     1.167629  1.229798
# 9992   0.694896 -0.864161      0.0 -1.264507 -1.247640     1.167629  1.229798
# 9993  -0.213513 -0.864161      0.0  1.703494 -1.247640     1.169375  1.229798
#
# ...
